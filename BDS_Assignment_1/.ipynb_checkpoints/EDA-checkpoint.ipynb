# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %%
# !ls data/
# Out:
# country_wise_latest.csv      day_wise.csv      usa_county_wise.csv
# covid_19_clean_complete.csv  full_grouped.csv  worldometer_data.csv

# %%
country_df = pd.read_csv("data/country_wise_latest.csv")
day_df = pd.read_csv("data/day_wise.csv")
covid_19_df = pd.read_csv("data/covid_19_clean_complete.csv")
full_grouped_df = pd.read_csv("data/full_grouped.csv")
world_df = pd.read_csv("data/worldometer_data.csv")

# %% [markdown]
# # Q1

# %%
country_df.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
# Number of new cases
country_df["New cases"].sum(), country_df["New deaths"].sum(), country_df["New recovered"].sum()
# Out:
# (228693, 5415, 174623)

# %% [markdown]
# # Q2

# %%
world_df.head(2)
# Out:
#   Country/Region      Continent   Population  TotalCases  NewCases  \
# 0            USA  North America  331198130.0     5032179       NaN
# 1         Brazil  South America  212710692.0     2917562       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# 1            8318.0           13716.0          464.0  13206188.0
#
#    Tests/1M pop WHO Region
# 0      190640.0   Americas
# 1       62085.0   Americas

# %%
asia_cases = world_df[world_df.Continent == "Asia"]

# %%
asia_cases.groupby(by = ["Country/Region", "WHO Region"])["TotalDeaths"].sum()
# Out:
# Country/Region  WHO Region
# Afghanistan     EasternMediterranean     1298.0
# Armenia         Europe                    772.0
# Azerbaijan      Europe                    479.0
# Bahrain         EasternMediterranean      156.0
# Bangladesh      South-EastAsia           3306.0
# Bhutan          South-EastAsia              0.0
# Cambodia        WesternPacific              0.0
# Cyprus          Europe                     19.0
# Georgia         Europe                     17.0
# Hong Kong       WesternPacific             46.0
# India           South-EastAsia          41638.0
# Indonesia       South-EastAsia           5521.0
# Iran            EasternMediterranean    17976.0
# Iraq            EasternMediterranean     5161.0
# Israel          Europe                    576.0
# Japan           WesternPacific           1026.0
# Jordan          EasternMediterranean       11.0
# Kazakhstan      Europe                   1058.0
# Kuwait          EasternMediterranean      469.0
# ...

# %% [markdown]
# # Q3

# %%
day_df.head(2)
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8

# %%
day_df[day_df.Date == "2020-02-12"]["Deaths"].item()
# Out:
# 1118

# %% [markdown]
# # Q4

# %%
country_df["active_new"] = country_df["New cases"] - (country_df["New deaths"] + country_df["New recovered"])

# %%
country_df.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region  active_new
# 0               2.07  Eastern Mediterranean          78
# 1              17.00                 Europe          48

# %%
country_df.sort_values(by = ["Country/Region"], ascending = False)[["Country/Region", "active_new"]]
# Out:
#          Country/Region  active_new
# 186            Zimbabwe         166
# 185              Zambia        -395
# 184               Yemen         -30
# 183      Western Sahara           0
# 182  West Bank and Gaza         150
# ..                  ...         ...
# 4                Angola          17
# 3               Andorra          10
# 2               Algeria        -141
# 1               Albania          48
# 0           Afghanistan          78
#
# [187 rows x 2 columns]

# %% [markdown]
# # Q5

# %%
country_df.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region  active_new
# 0               2.07  Eastern Mediterranean          78
# 1              17.00                 Europe          48

# %%
country_df[(country_df.Active >= 9000) & (country_df.Deaths >=800)].iloc[:, 0]
# Out:
# 0             Afghanistan
# 6               Argentina
# 13             Bangladesh
# 16                Belgium
# 20                Bolivia
# 23                 Brazil
# 32                 Canada
# 35                  Chile
# 37               Colombia
# 50     Dominican Republic
# 51                Ecuador
# 52                  Egypt
# 61                 France
# 70              Guatemala
# 76               Honduras
# 79                  India
# 80              Indonesia
# 81                   Iran
# 82                   Iraq
# 85                  Italy
# 93             Kyrgyzstan
# 111                Mexico
# 120           Netherlands
# 124               Nigeria
# 128              Pakistan
# 129                Panama
# 132                  Peru
# 133           Philippines
# 135              Portugal
# 137               Romania
# 138                Russia
# 145          Saudi Arabia
# 154          South Africa
# 157                 Spain
# 161                Sweden
# ...

# %% [markdown]
# # Q6

# %%
country_df.sort_values(by = ["Active"], ascending = False).head(1)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region  active_new
# 173              11.88   Americas       27319

# %%
country_df.sort_values(by = ["Deaths / 100 Cases"], ascending = False).head(2).tail(1)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 177  United Kingdom     301708   45844       1437  254427        688
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 177           7              3               15.19                   0.48
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 177                 3190.26               296944           4764
#
#      1 week % increase WHO Region  active_new
# 177                1.6     Europe         678

# %% [markdown]
# # Q7

# %%
country_df.Deaths.sum()
# Out:
# 654036

# %% [markdown]
# # Q8

# %%
day_df["Date"] = pd.to_datetime(day_df.Date)

# %%
from datetime import datetime
sub_df = day_df[(day_df.Date >= datetime(2020, 1, 28)) & (day_df.Date <= datetime(2020,2,21))]

# %%
sub_df.Active.sum(), sub_df.Deaths.sum()
# Out:
# (886425, 25885)

# %% [markdown]
# # Q9

# %%
covid_19_df.head(2)
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe

# %%
sub_df = covid_19_df[covid_19_df["Country/Region"].apply(lambda x: x.endswith("ia"))]

# %%
len(sub_df)
# Out:
# 8460

# %%
sub_df[["Country/Region", "Lat", "Long"]]
# Out:
#       Country/Region        Lat        Long
# 1            Albania  41.153300   20.168300
# 2            Algeria  28.033900    1.659600
# 7            Armenia  40.069100   45.038200
# 8          Australia -35.473500  149.012400
# 9          Australia -33.868800  151.209300
# ...              ...        ...         ...
# 49004        Somalia   5.152149   46.199616
# 49013       Tanzania  -6.369028   34.888822
# 49017        Tunisia  33.886917    9.537499
# 49034         Zambia -13.133897   27.849332
# 49039          Syria  34.802075   38.996815
#
# [8460 rows x 3 columns]

# %% [markdown]
# # Q10

# %%
full_grouped_df.head(2)
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe

# %%
sub_df = full_grouped_df[full_grouped_df.Date == "2020-03-30"]

# %%
sub_df[sub_df.Active > 0]["Country/Region"]
# Out:
# 12716           Afghanistan
# 12717               Albania
# 12718               Algeria
# 12719               Andorra
# 12720                Angola
#                 ...
# 12896             Venezuela
# 12897               Vietnam
# 12898    West Bank and Gaza
# 12901                Zambia
# 12902              Zimbabwe
# Name: Country/Region, Length: 176, dtype: object

# %% [markdown]
# # Q11

# %%
covid_19_df[covid_19_df.Active > 100][["Country/Region", "Lat", "Long"]]
# Out:
#               Country/Region        Lat        Long
# 61                     China  30.975600  112.270700
# 322                    China  30.975600  112.270700
# 583                    China  30.975600  112.270700
# 844                    China  30.975600  112.270700
# 1097                   China  23.341700  113.424400
# ...                      ...        ...         ...
# 49061            South Sudan   6.877000   31.307000
# 49063  Sao Tome and Principe   0.186400    6.613100
# 49064                  Yemen  15.552727   48.516388
# 49066             Tajikistan  38.861000   71.276100
# 49067                Lesotho -29.610000   28.233600
#
# [19661 rows x 3 columns]

# %% [markdown]
# # Q12

# %%
full_grouped_df.head(2)
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe

# %%
full_grouped_df["Increase"] = full_grouped_df["New cases"] - full_grouped_df["Active"]

# %%
sub_df = full_grouped_df[["Date", "Country/Region", "Increase"]]

# %%
sub_df.sort_values(by = ["Increase"], ascending = False)
# Out:
#              Date Country/Region  Increase
# 22188  2020-05-19      Nicaragua       191
# 23497  2020-05-26      Nicaragua       126
# 24687  2020-06-02        Andorra        19
# 32379  2020-07-13        Burundi        17
# 33834  2020-07-20         Uganda         6
# ...           ...            ...       ...
# 34394  2020-07-23             US  -2592422
# 34581  2020-07-24             US  -2631632
# 34768  2020-07-25             US  -2686652
# 34955  2020-07-26             US  -2734172
# 35142  2020-07-27             US  -2760108
#
# [35156 rows x 3 columns]
